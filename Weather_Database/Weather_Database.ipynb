# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Step 3 Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Step 3a Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Step 4 Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#Step 4a Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
#Step 5 Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=47a9492de94be05a37094596abe3157d

# %%
#Step 5a Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Step 6 Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | koungou
# Processing Record 3 of Set 1 | agirish
# Processing Record 4 of Set 1 | alice springs
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | tautira
# Processing Record 7 of Set 1 | bengkulu
# Processing Record 8 of Set 1 | matara
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 11 of Set 1 | byron bay
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | zhmerynka
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | mayo
# Processing Record 18 of Set 1 | faya
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | marathon
# Processing Record 23 of Set 1 | san ciro de acosta
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | teya
# Processing Record 27 of Set 1 | naze
# Processing Record 28 of Set 1 | zheleznodorozhnyy
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | kruisfontein
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | lata
# Processing Record 34 of Set 1 | asyut
# Processing Record 35 of Set 1 | tateyama
# Processing Record 36 of Set 1 | komsomolskiy
# Processing Record 37 of Set 1 | turmalina
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | cedar city
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | gold coast
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | bandarbeyla
# Processing Record 1 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 2 | doha
# Processing Record 3 of Set 2 | mandalgovi
# Processing Record 4 of Set 2 | camopi
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | ingham
# Processing Record 8 of Set 2 | shelburne
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 2 | gilleleje
# Processing Record 13 of Set 2 | portland
# Processing Record 14 of Set 2 | puro
# Processing Record 15 of Set 2 | samarai
# Processing Record 16 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 2 | itaituba
# Processing Record 18 of Set 2 | manyana
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | taoudenni
# Processing Record 22 of Set 2 | turochak
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | alugan
# Processing Record 26 of Set 2 | batemans bay
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | ayan
# Processing Record 31 of Set 2 | beirut
# Processing Record 32 of Set 2 | sorland
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | zhezkazgan
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | gloversville
# Processing Record 39 of Set 2 | novosheshminsk
# Processing Record 40 of Set 2 | awjilah
# Processing Record 41 of Set 2 | abalak
# Processing Record 42 of Set 2 | okhotsk
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | isiro
# Processing Record 46 of Set 2 | kawambwa
# Processing Record 47 of Set 2 | rawlins
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | dothan
# Processing Record 50 of Set 2 | rio gallegos
# Processing Record 1 of Set 3 | sao filipe
# Processing Record 2 of Set 3 | rikitea
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | aripuana
# Processing Record 5 of Set 3 | laurel
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | greenfield
# Processing Record 8 of Set 3 | tommot
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | tarecuato
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | zhifang
# Processing Record 15 of Set 3 | rio verde de mato grosso
# Processing Record 16 of Set 3 | fernie
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | greymouth
# Processing Record 20 of Set 3 | manaure
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | boueni
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | recke
# Processing Record 26 of Set 3 | suraabad
# Processing Record 27 of Set 3 | srednekolymsk
# Processing Record 28 of Set 3 | fare
# Processing Record 29 of Set 3 | marystown
# Processing Record 30 of Set 3 | bud
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | tibati
# Processing Record 33 of Set 3 | barrow
# Processing Record 34 of Set 3 | hilo
# Processing Record 35 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 36 of Set 3 | visnes
# Processing Record 37 of Set 3 | gamboula
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | cap malheureux
# Processing Record 40 of Set 3 | acarau
# Processing Record 41 of Set 3 | port alberni
# Processing Record 42 of Set 3 | nesna
# Processing Record 43 of Set 3 | porto santo
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | clyde river
# Processing Record 47 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 3 | xingyi
# Processing Record 49 of Set 3 | luganville
# Processing Record 50 of Set 3 | shellbrook
# Processing Record 1 of Set 4 | anadyr
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | luangwa
# Processing Record 4 of Set 4 | sur
# Processing Record 5 of Set 4 | nanortalik
# Processing Record 6 of Set 4 | broome
# Processing Record 7 of Set 4 | mpulungu
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | upington
# Processing Record 10 of Set 4 | rhyl
# Processing Record 11 of Set 4 | dezhou
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | waingapu
# Processing Record 14 of Set 4 | bluff
# Processing Record 15 of Set 4 | san isidro
# Processing Record 16 of Set 4 | saurimo
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | tlacotepec
# Processing Record 20 of Set 4 | jalu
# Processing Record 21 of Set 4 | dapaong
# Processing Record 22 of Set 4 | pindushi
# Processing Record 23 of Set 4 | humberto de campos
# Processing Record 24 of Set 4 | hamilton
# Processing Record 25 of Set 4 | puerto escondido
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | alapur
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | aitape
# Processing Record 31 of Set 4 | grand gaube
# Processing Record 32 of Set 4 | ahar
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | joshimath
# Processing Record 35 of Set 4 | scottsbluff
# Processing Record 36 of Set 4 | sistranda
# Processing Record 37 of Set 4 | poum
# Processing Record 38 of Set 4 | hervey bay
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | wattegama
# Processing Record 41 of Set 4 | fuente de oro
# Processing Record 42 of Set 4 | faanui
# Processing Record 43 of Set 4 | abha
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | salinopolis
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | vung tau
# Processing Record 49 of Set 4 | akureyri
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | abu kamal
# Processing Record 2 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 5 | kuryk
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | puerto cabezas
# Processing Record 6 of Set 5 | kantang
# Processing Record 7 of Set 5 | pocatello
# Processing Record 8 of Set 5 | cumra
# Processing Record 9 of Set 5 | saint-pierre
# Processing Record 10 of Set 5 | lujan
# Processing Record 11 of Set 5 | yatou
# Processing Record 12 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 5 | melo
# Processing Record 14 of Set 5 | ahipara
# Processing Record 15 of Set 5 | san jeronimo
# Processing Record 16 of Set 5 | esterhazy
# Processing Record 17 of Set 5 | talnakh
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | isangel
# Processing Record 20 of Set 5 | praia
# Processing Record 21 of Set 5 | beyneu
# Processing Record 22 of Set 5 | karpinsk
# Processing Record 23 of Set 5 | puerto ayora
# Processing Record 24 of Set 5 | bonthe
# Processing Record 25 of Set 5 | constitucion
# Processing Record 26 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | mumford
# Processing Record 29 of Set 5 | benghazi
# Processing Record 30 of Set 5 | strezhevoy
# Processing Record 31 of Set 5 | comodoro rivadavia
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 34 of Set 5 | san quintin
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | hambantota
# Processing Record 39 of Set 5 | bitung
# Processing Record 40 of Set 5 | makakilo city
# Processing Record 41 of Set 5 | leningradskiy
# Processing Record 42 of Set 5 | burnie
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | corinto
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | karratha
# Processing Record 47 of Set 5 | wucheng
# Processing Record 48 of Set 5 | central point
# Processing Record 49 of Set 5 | baiao
# Processing Record 50 of Set 5 | saskylakh
# Processing Record 1 of Set 6 | naivasha
# Processing Record 2 of Set 6 | hokitika
# Processing Record 3 of Set 6 | privokzalnyy
# City not found. Skipping...
# Processing Record 4 of Set 6 | opuwo
# Processing Record 5 of Set 6 | mecca
# Processing Record 6 of Set 6 | murray bridge
# Processing Record 7 of Set 6 | dingle
# Processing Record 8 of Set 6 | kushmurun
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | moree
# Processing Record 11 of Set 6 | ouesso
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | kamiichi
# Processing Record 14 of Set 6 | boralday
# Processing Record 15 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 16 of Set 6 | lazaro cardenas
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | beira
# Processing Record 19 of Set 6 | cherskiy
# Processing Record 20 of Set 6 | gorontalo
# Processing Record 21 of Set 6 | sisimiut
# Processing Record 22 of Set 6 | englewood
# Processing Record 23 of Set 6 | bisert
# Processing Record 24 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 6 | mersin
# Processing Record 26 of Set 6 | redhakhol
# City not found. Skipping...
# Processing Record 27 of Set 6 | casper
# Processing Record 28 of Set 6 | kenai
# Processing Record 29 of Set 6 | kamakwie
# Processing Record 30 of Set 6 | los lunas
# Processing Record 31 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 6 | lavrentiya
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | molochnoye
# Processing Record 35 of Set 6 | shimoda
# Processing Record 36 of Set 6 | jadu
# Processing Record 37 of Set 6 | mareeba
# Processing Record 38 of Set 6 | yerbogachen
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | tyret pervaya
# Processing Record 44 of Set 6 | aras
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | jawhar
# Processing Record 47 of Set 6 | port hedland
# Processing Record 48 of Set 6 | vao
# Processing Record 49 of Set 6 | altar
# Processing Record 50 of Set 6 | tezu
# Processing Record 1 of Set 7 | amapa
# Processing Record 2 of Set 7 | san patricio
# Processing Record 3 of Set 7 | surt
# Processing Record 4 of Set 7 | khuzdar
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | copiapo
# Processing Record 7 of Set 7 | nampula
# Processing Record 8 of Set 7 | boa vista
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | kirakira
# Processing Record 11 of Set 7 | kieta
# Processing Record 12 of Set 7 | challapata
# Processing Record 13 of Set 7 | north bend
# Processing Record 14 of Set 7 | nyurba
# Processing Record 15 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 7 | bilma
# Processing Record 17 of Set 7 | berlevag
# Processing Record 18 of Set 7 | ploemeur
# Processing Record 19 of Set 7 | tiksi
# Processing Record 20 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 7 | pemberton
# Processing Record 22 of Set 7 | hofn
# Processing Record 23 of Set 7 | flinders
# Processing Record 24 of Set 7 | avdon
# Processing Record 25 of Set 7 | atchison
# Processing Record 26 of Set 7 | balykshi
# Processing Record 27 of Set 7 | tungor
# Processing Record 28 of Set 7 | topeka
# Processing Record 29 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | la ronge
# Processing Record 32 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 7 | coquimbo
# Processing Record 34 of Set 7 | kununurra
# Processing Record 35 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 7 | kaeo
# Processing Record 37 of Set 7 | del rio
# Processing Record 38 of Set 7 | salihorsk
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | nouakchott
# Processing Record 41 of Set 7 | liepaja
# Processing Record 42 of Set 7 | newton
# Processing Record 43 of Set 7 | miraflores
# Processing Record 44 of Set 7 | cabedelo
# Processing Record 45 of Set 7 | kampot
# Processing Record 46 of Set 7 | sobolevo
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | fortuna
# Processing Record 49 of Set 7 | vestmannaeyjar
# Processing Record 50 of Set 7 | talara
# Processing Record 1 of Set 8 | souillac
# Processing Record 2 of Set 8 | lorengau
# Processing Record 3 of Set 8 | hasaki
# Processing Record 4 of Set 8 | san andres
# Processing Record 5 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 8 | vila velha
# Processing Record 7 of Set 8 | hobyo
# Processing Record 8 of Set 8 | villa union
# Processing Record 9 of Set 8 | bay roberts
# Processing Record 10 of Set 8 | ballina
# Processing Record 11 of Set 8 | yeppoon
# Processing Record 12 of Set 8 | riyadh
# Processing Record 13 of Set 8 | san cristobal
# Processing Record 14 of Set 8 | kutum
# Processing Record 15 of Set 8 | vryheid
# Processing Record 16 of Set 8 | weyburn
# Processing Record 17 of Set 8 | lima
# Processing Record 18 of Set 8 | iqaluit
# Processing Record 19 of Set 8 | taman
# Processing Record 20 of Set 8 | hanover
# Processing Record 21 of Set 8 | pisco
# Processing Record 22 of Set 8 | bermeo
# Processing Record 23 of Set 8 | rio branco
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | san joaquin
# Processing Record 26 of Set 8 | simbahan
# Processing Record 27 of Set 8 | moerai
# Processing Record 28 of Set 8 | krasnoselkup
# Processing Record 29 of Set 8 | oranjestad
# Processing Record 30 of Set 8 | shumikha
# Processing Record 31 of Set 8 | brae
# Processing Record 32 of Set 8 | xining
# Processing Record 33 of Set 8 | kuusamo
# Processing Record 34 of Set 8 | pringsewu
# Processing Record 35 of Set 8 | awbari
# Processing Record 36 of Set 8 | bethel
# Processing Record 37 of Set 8 | dondo
# Processing Record 38 of Set 8 | waipawa
# Processing Record 39 of Set 8 | pechory
# Processing Record 40 of Set 8 | the valley
# Processing Record 41 of Set 8 | grindavik
# Processing Record 42 of Set 8 | tekeli
# Processing Record 43 of Set 8 | mazagao
# Processing Record 44 of Set 8 | najran
# Processing Record 45 of Set 8 | vanderhoof
# Processing Record 46 of Set 8 | velasco ibarra
# Processing Record 47 of Set 8 | kuopio
# Processing Record 48 of Set 8 | veraval
# Processing Record 49 of Set 8 | charyshskoye
# Processing Record 50 of Set 8 | sibolga
# Processing Record 1 of Set 9 | morro bay
# Processing Record 2 of Set 9 | duku
# Processing Record 3 of Set 9 | balyaga
# Processing Record 4 of Set 9 | cleveland
# Processing Record 5 of Set 9 | maragogi
# Processing Record 6 of Set 9 | san jose
# Processing Record 7 of Set 9 | medina
# Processing Record 8 of Set 9 | vostok
# Processing Record 9 of Set 9 | naushki
# Processing Record 10 of Set 9 | luderitz
# Processing Record 11 of Set 9 | jorhat
# Processing Record 12 of Set 9 | touros
# Processing Record 13 of Set 9 | sangre grande
# Processing Record 14 of Set 9 | porto walter
# Processing Record 15 of Set 9 | kenora
# Processing Record 16 of Set 9 | sao joao da barra
# Processing Record 17 of Set 9 | zhanaozen
# Processing Record 18 of Set 9 | lodhikheda
# Processing Record 19 of Set 9 | batagay-alyta
# Processing Record 20 of Set 9 | sola
# Processing Record 21 of Set 9 | itatiaia
# Processing Record 22 of Set 9 | phan thiet
# Processing Record 23 of Set 9 | kargasok
# Processing Record 24 of Set 9 | bereda
# Processing Record 25 of Set 9 | shaoxing
# Processing Record 26 of Set 9 | muscat
# Processing Record 27 of Set 9 | ngunguru
# Processing Record 28 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 9 | cam ranh
# Processing Record 30 of Set 9 | zyryanka
# Processing Record 31 of Set 9 | romodanovo
# Processing Record 32 of Set 9 | maniitsoq
# Processing Record 33 of Set 9 | poshekhonye
# Processing Record 34 of Set 9 | pribelskiy
# City not found. Skipping...
# Processing Record 35 of Set 9 | kamenka
# Processing Record 36 of Set 9 | payakumbuh
# Processing Record 37 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 38 of Set 9 | nioro
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | ussel
# Processing Record 41 of Set 9 | svetlogorsk
# Processing Record 42 of Set 9 | mayachnyy
# Processing Record 43 of Set 9 | mosquera
# Processing Record 44 of Set 9 | ribeira grande
# Processing Record 45 of Set 9 | papar
# Processing Record 46 of Set 9 | kathmandu
# Processing Record 47 of Set 9 | tura
# Processing Record 48 of Set 9 | alta
# Processing Record 49 of Set 9 | san pedro
# Processing Record 50 of Set 9 | usinsk
# Processing Record 1 of Set 10 | shushenskoye
# Processing Record 2 of Set 10 | hun
# Processing Record 3 of Set 10 | dhamrai
# Processing Record 4 of Set 10 | burica
# City not found. Skipping...
# Processing Record 5 of Set 10 | grandview
# Processing Record 6 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 10 | dukat
# Processing Record 8 of Set 10 | bintulu
# Processing Record 9 of Set 10 | guerrero negro
# Processing Record 10 of Set 10 | dosso
# Processing Record 11 of Set 10 | jumla
# Processing Record 12 of Set 10 | zhigansk
# Processing Record 13 of Set 10 | diamantino
# Processing Record 14 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 15 of Set 10 | altay
# Processing Record 16 of Set 10 | zhengjiatun
# Processing Record 17 of Set 10 | bathsheba
# Processing Record 18 of Set 10 | north platte
# Processing Record 19 of Set 10 | tulu bolo
# Processing Record 20 of Set 10 | matay
# Processing Record 21 of Set 10 | asau
# Processing Record 22 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 23 of Set 10 | kamenskiy
# Processing Record 24 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 10 | manduria
# Processing Record 26 of Set 10 | mitu
# Processing Record 27 of Set 10 | great yarmouth
# Processing Record 28 of Set 10 | dalbandin
# Processing Record 29 of Set 10 | thohoyandou
# Processing Record 30 of Set 10 | acapulco
# Processing Record 31 of Set 10 | bairiki
# Processing Record 32 of Set 10 | scarborough
# Processing Record 33 of Set 10 | yarmouth
# Processing Record 34 of Set 10 | nokaneng
# Processing Record 35 of Set 10 | oriximina
# Processing Record 36 of Set 10 | nizwa
# Processing Record 37 of Set 10 | hohhot
# Processing Record 38 of Set 10 | ulaanbaatar
# Processing Record 39 of Set 10 | alta floresta
# Processing Record 40 of Set 10 | kangaba
# Processing Record 41 of Set 10 | nouadhibou
# Processing Record 42 of Set 10 | sandy bay
# Processing Record 43 of Set 10 | carutapera
# Processing Record 44 of Set 10 | shenjiamen
# Processing Record 45 of Set 10 | ashington
# Processing Record 46 of Set 10 | plettenberg bay
# Processing Record 47 of Set 10 | kloulklubed
# Processing Record 48 of Set 10 | axim
# Processing Record 49 of Set 10 | hami
# Processing Record 50 of Set 10 | ostrovnoy
# Processing Record 1 of Set 11 | port blair
# Processing Record 2 of Set 11 | gezing
# Processing Record 3 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 11 | chumikan
# Processing Record 5 of Set 11 | soe
# Processing Record 6 of Set 11 | paka
# Processing Record 7 of Set 11 | atar
# Processing Record 8 of Set 11 | tilichiki
# Processing Record 9 of Set 11 | qui nhon
# Processing Record 10 of Set 11 | nyagan
# Processing Record 11 of Set 11 | quatre cocos
# Processing Record 12 of Set 11 | nara
# Processing Record 13 of Set 11 | sorrento
# Processing Record 14 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 11 | carmelo
# Processing Record 16 of Set 11 | christchurch
# Processing Record 17 of Set 11 | tsumeb
# Processing Record 18 of Set 11 | yazman
# Processing Record 19 of Set 11 | ouahigouya
# Processing Record 20 of Set 11 | biloela
# Processing Record 21 of Set 11 | ketchikan
# Processing Record 22 of Set 11 | gat
# Processing Record 23 of Set 11 | shenzhen
# Processing Record 24 of Set 11 | san-pedro
# Processing Record 25 of Set 11 | katakwi
# Processing Record 26 of Set 11 | kyaukse
# Processing Record 27 of Set 11 | ewa beach
# Processing Record 28 of Set 11 | romny
# Processing Record 29 of Set 11 | ammon
# Processing Record 30 of Set 11 | saravan
# Processing Record 31 of Set 11 | harrison
# Processing Record 32 of Set 11 | laguna
# Processing Record 33 of Set 11 | severomuysk
# Processing Record 34 of Set 11 | seoul
# Processing Record 35 of Set 11 | antsohihy
# Processing Record 36 of Set 11 | chiang klang
# Processing Record 37 of Set 11 | biltine
# Processing Record 38 of Set 11 | moron
# Processing Record 39 of Set 11 | takoradi
# Processing Record 40 of Set 11 | ampanihy
# Processing Record 41 of Set 11 | imbituba
# Processing Record 42 of Set 11 | deer lake
# Processing Record 43 of Set 11 | sao jose da coroa grande
# Processing Record 44 of Set 11 | bwanga
# Processing Record 45 of Set 11 | dwarka
# Processing Record 46 of Set 11 | kem
# Processing Record 47 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 11 | kahului
# Processing Record 49 of Set 11 | portalegre
# Processing Record 50 of Set 11 | mackay
# Processing Record 1 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 12 | vidisha
# Processing Record 3 of Set 12 | cerro largo
# Processing Record 4 of Set 12 | maba
# Processing Record 5 of Set 12 | urumqi
# Processing Record 6 of Set 12 | ialibu
# Processing Record 7 of Set 12 | svetlyy
# Processing Record 8 of Set 12 | narayanpet
# Processing Record 9 of Set 12 | turayf
# Processing Record 10 of Set 12 | tambacounda
# Processing Record 11 of Set 12 | zhuhai
# Processing Record 12 of Set 12 | pontes e lacerda
# Processing Record 13 of Set 12 | estacion coahuila
# Processing Record 14 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 12 | inhambane
# Processing Record 16 of Set 12 | padang
# Processing Record 17 of Set 12 | mariental
# Processing Record 18 of Set 12 | manta
# Processing Record 19 of Set 12 | ambilobe
# Processing Record 20 of Set 12 | black river
# Processing Record 21 of Set 12 | mount isa
# Processing Record 22 of Set 12 | broken hill
# Processing Record 23 of Set 12 | sambava
# Processing Record 24 of Set 12 | buldana
# Processing Record 25 of Set 12 | mersing
# Processing Record 26 of Set 12 | tadine
# Processing Record 27 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 12 | san vicente
# Processing Record 29 of Set 12 | saint-paul
# Processing Record 30 of Set 12 | wukari
# Processing Record 31 of Set 12 | santa maria
# Processing Record 32 of Set 12 | storforshei
# Processing Record 33 of Set 12 | labuhan
# Processing Record 34 of Set 12 | husavik
# Processing Record 35 of Set 12 | zvenigovo
# Processing Record 36 of Set 12 | parkes
# Processing Record 37 of Set 12 | apricena
# Processing Record 38 of Set 12 | nemuro
# Processing Record 39 of Set 12 | agadir
# Processing Record 40 of Set 12 | terney
# Processing Record 41 of Set 12 | vysokogornyy
# Processing Record 42 of Set 12 | tongliao
# Processing Record 43 of Set 12 | verkhoturye
# Processing Record 44 of Set 12 | san lorenzo
# Processing Record 45 of Set 12 | fomboni
# Processing Record 46 of Set 12 | namtsy
# Processing Record 47 of Set 12 | babynino
# Processing Record 48 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 12 | san pedro de cajas
# Processing Record 50 of Set 12 | kurilsk
# Processing Record 1 of Set 13 | baoqing
# Processing Record 2 of Set 13 | nhulunbuy
# Processing Record 3 of Set 13 | kumba
# Processing Record 4 of Set 13 | fukue
# Processing Record 5 of Set 13 | jawa
# Processing Record 6 of Set 13 | richards bay
# Processing Record 7 of Set 13 | gamba
# Processing Record 8 of Set 13 | namatanai
# Processing Record 9 of Set 13 | rawson
# Processing Record 10 of Set 13 | jackson
# Processing Record 11 of Set 13 | stokmarknes
# Processing Record 12 of Set 13 | ulladulla
# Processing Record 13 of Set 13 | la asuncion
# Processing Record 14 of Set 13 | caraballeda
# Processing Record 15 of Set 13 | tiznit
# Processing Record 16 of Set 13 | xihua
# Processing Record 17 of Set 13 | la orilla
# Processing Record 18 of Set 13 | plouzane
# Processing Record 19 of Set 13 | chernyakhovsk
# Processing Record 20 of Set 13 | iberia
# Processing Record 21 of Set 13 | auki
# Processing Record 22 of Set 13 | pingzhuang
# Processing Record 23 of Set 13 | nabire
# Processing Record 24 of Set 13 | nago
# Processing Record 25 of Set 13 | havelock
# Processing Record 26 of Set 13 | pingliang
# Processing Record 27 of Set 13 | praia da vitoria
# Processing Record 28 of Set 13 | cheyenne
# Processing Record 29 of Set 13 | maltahohe
# Processing Record 30 of Set 13 | tigil
# Processing Record 31 of Set 13 | maputo
# Processing Record 32 of Set 13 | santa cruz
# Processing Record 33 of Set 13 | wangqing
# Processing Record 34 of Set 13 | galle
# Processing Record 35 of Set 13 | coralville
# Processing Record 36 of Set 13 | shache
# Processing Record 37 of Set 13 | rio grande
# Processing Record 38 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 13 | kokopo
# Processing Record 40 of Set 13 | dabhol
# Processing Record 41 of Set 13 | los llanos de aridane
# Processing Record 42 of Set 13 | kardla
# Processing Record 43 of Set 13 | gravdal
# Processing Record 44 of Set 13 | kibala
# Processing Record 45 of Set 13 | ust-kut
# Processing Record 46 of Set 13 | chapais
# Processing Record 47 of Set 13 | cooma
# Processing Record 48 of Set 13 | ous
# Processing Record 49 of Set 13 | amazar
# Processing Record 50 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 14 | vallenar
# Processing Record 3 of Set 14 | ambarnath
# Processing Record 4 of Set 14 | northam
# Processing Record 5 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 6 of Set 14 | taikang
# Processing Record 7 of Set 14 | ust-tsilma
# Processing Record 8 of Set 14 | brigham city
# Processing Record 9 of Set 14 | swift current
# Processing Record 10 of Set 14 | norman
# Processing Record 11 of Set 14 | russellville
# Processing Record 12 of Set 14 | papantla
# City not found. Skipping...
# Processing Record 13 of Set 14 | buta
# Processing Record 14 of Set 14 | san francisco
# Processing Record 15 of Set 14 | rathdrum
# Processing Record 16 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 14 | thinadhoo
# Processing Record 18 of Set 14 | ponta delgada
# Processing Record 19 of Set 14 | bambanglipuro
# Processing Record 20 of Set 14 | erdenet
# Processing Record 21 of Set 14 | parral
# Processing Record 22 of Set 14 | melle
# Processing Record 23 of Set 14 | saumur
# Processing Record 24 of Set 14 | cap-aux-meules
# Processing Record 25 of Set 14 | mehamn
# Processing Record 26 of Set 14 | miracema do tocantins
# Processing Record 27 of Set 14 | nha trang
# Processing Record 28 of Set 14 | beatrice
# Processing Record 29 of Set 14 | verkhovazhye
# Processing Record 30 of Set 14 | ust-kuyga
# Processing Record 31 of Set 14 | wilmington
# Processing Record 32 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 14 | fuyu
# Processing Record 34 of Set 14 | la reforma
# Processing Record 35 of Set 14 | huntington
# Processing Record 36 of Set 14 | taquara
# Processing Record 37 of Set 14 | guadalupe y calvo
# Processing Record 38 of Set 14 | zahirabad
# Processing Record 39 of Set 14 | montevista
# Processing Record 40 of Set 14 | kavieng
# Processing Record 41 of Set 14 | baruun-urt
# Processing Record 42 of Set 14 | santa maria do suacui
# Processing Record 43 of Set 14 | mogadishu
# Processing Record 44 of Set 14 | florida
# Processing Record 45 of Set 14 | tezpur
# Processing Record 46 of Set 14 | taos
# Processing Record 47 of Set 14 | thunder bay
# Processing Record 48 of Set 14 | mpophomeni
# Processing Record 49 of Set 14 | puerto palomas
# Processing Record 50 of Set 14 | seymchan
# Processing Record 1 of Set 15 | boma
# Processing Record 2 of Set 15 | inongo
# Processing Record 3 of Set 15 | sulangan
# Processing Record 4 of Set 15 | tanabi
# Processing Record 5 of Set 15 | novosergiyevka
# Processing Record 6 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 15 | kirov
# Processing Record 8 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 15 | sumenep
# Processing Record 10 of Set 15 | igurusi
# Processing Record 11 of Set 15 | zlitan
# Processing Record 12 of Set 15 | cairns
# Processing Record 13 of Set 15 | pergamino
# Processing Record 14 of Set 15 | road town
# Processing Record 15 of Set 15 | tiarei
# Processing Record 16 of Set 15 | paengaroa
# Processing Record 17 of Set 15 | walvis bay
# Processing Record 18 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 15 | jiexiu
# Processing Record 20 of Set 15 | nangomba
# Processing Record 21 of Set 15 | goderich
# Processing Record 22 of Set 15 | itarema
# Processing Record 23 of Set 15 | santarem
# Processing Record 24 of Set 15 | raduzhnyy
# Processing Record 25 of Set 15 | lakatoro
# Processing Record 26 of Set 15 | consuegra
# Processing Record 27 of Set 15 | esmeralda
# Processing Record 28 of Set 15 | gogrial
# Processing Record 29 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 15 | arcachon
# Processing Record 31 of Set 15 | nome
# Processing Record 32 of Set 15 | charters towers
# Processing Record 33 of Set 15 | saveh
# Processing Record 34 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 15 | hirara
# Processing Record 36 of Set 15 | mount gambier
# Processing Record 37 of Set 15 | malvern
# Processing Record 38 of Set 15 | karlstad
# Processing Record 39 of Set 15 | cabra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cidreira      BR -30.1811  -50.2056     56.52        76         100
# 1        Koungou      YT -12.7336   45.2042     80.31        69          40
# 2        Agirish      RU  61.9247   63.0231     61.74        59          98
# 3  Alice Springs      AU -23.7000  133.8833     74.21        21           0
# 4         Torbay      CA  47.6666  -52.7314     42.28        78          40
# 5        Tautira      PF -17.7333 -149.1500     84.22        79          94
# 6       Bengkulu      ID  -3.8004  102.2655     79.50        84         100
# 7         Matara      LK   5.9485   80.5353     81.05        84          95
# 8     Georgetown      MY   5.4112  100.3354     82.33        86          20
# 9      Byron Bay      AU -28.6500  153.6167     71.87        65          16
#
#    Wind Speed Current Description
# 0        3.85     overcast clouds
# 1       19.82    scattered clouds
# 2        6.53     overcast clouds
# 3       11.99           clear sky
# 4       10.36    scattered clouds
# 5       20.71          light rain
# 6        2.13     overcast clouds
# 7        8.46     overcast clouds
# 8        1.99          few clouds
# 9        6.89          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cidreira      BR -30.1811  -50.2056     56.52        76         100
# 1        Koungou      YT -12.7336   45.2042     80.31        69          40
# 2        Agirish      RU  61.9247   63.0231     61.74        59          98
# 3  Alice Springs      AU -23.7000  133.8833     74.21        21           0
# 4         Torbay      CA  47.6666  -52.7314     42.28        78          40
# 5        Tautira      PF -17.7333 -149.1500     84.22        79          94
# 6       Bengkulu      ID  -3.8004  102.2655     79.50        84         100
# 7         Matara      LK   5.9485   80.5353     81.05        84          95
# 8     Georgetown      MY   5.4112  100.3354     82.33        86          20
# 9      Byron Bay      AU -28.6500  153.6167     71.87        65          16
#
#    Wind Speed Current Description
# 0        3.85     overcast clouds
# 1       19.82    scattered clouds
# 2        6.53     overcast clouds
# 3       11.99           clear sky
# 4       10.36    scattered clouds
# 5       20.71          light rain
# 6        2.13     overcast clouds
# 7        8.46     overcast clouds
# 8        1.99          few clouds
# 9        6.89          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
